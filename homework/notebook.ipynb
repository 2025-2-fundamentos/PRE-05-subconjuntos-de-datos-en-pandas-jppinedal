# %%
import pandas as pd

pd.set_option('display.notebook_repr_html', True)

# %%
#carga  del archvio desde un repo de github
truck_events = pd.read_csv("../files/input/truck_event_text_partition.csv")

truck_events.head()
